# %%
#imports
import kagglehub
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import brier_score_loss
import matplotlib.pyplot as plt
import os
import pandas as pd


# Download latest version
path = kagglehub.dataset_download("nishaanamin/march-madness-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/frankmclaughlin/.cache/kagglehub/datasets/nishaanamin/march-madness-data/versions/145

# %%
for file in os.listdir(path):
    print(file)
# Out:
# Conference Stats Away Neutral.csv
# TeamRankings.csv
# RPPF Preseason Ratings.csv
# 538 Ratings.csv
# Barttorvik Away-Neutral.csv
# Z Rating Cumulative.csv
# Barttorvik Away.csv
# Z Rating Teams.csv
# Resumes.csv
# Upset Seed Info.csv
# EvanMiya.csv
# Tournament Locations.csv
# AP Poll Data.csv
# RPPF Ratings.csv
# Barttorvik Neutral.csv
# Barttorvik Home.csv
# Team Results.csv
# Conference Stats.csv
# Coach Results.csv
# Teamsheet Ranks.csv
# KenPom Barttorvik.csv
# Shooting Splits.csv
# Heat Check Tournament Index.csv
# TeamRankings Home.csv
# Public Picks.csv
# Seed Results.csv
# Tournament Matchups.csv
# Conference Stats Away.csv
# Upset Count.csv
# Heat Check Ratings.csv
# RPPF Conference Ratings.csv
# TeamRankings Away.csv
# Conference Stats Home.csv
# Tournament Simulation.csv
# KenPom Preseason.csv
# TeamRankings Neutral.csv
# Conference Stats Neutral.csv
# Conference Results.csv

# %%
# Replace 'filename.csv' with whatever shows up from the cell above
df = pd.read_csv(path + '/AP Poll Data.csv')
print(df.shape)      # how many rows and columns
print(df.head())     # first 5 rows
print(df.columns)    # all column names
# Out:
# (15372, 11)
#    YEAR  WEEK  TEAM NO         TEAM  SEED  ROUND    W    L  AP VOTES  AP RANK  \
# 0  2025     1   1123.0       Kansas   7.0   64.0  0.0  0.0    1449.0      1.0
# 1  2025     1   1146.0      Alabama   2.0    8.0  0.0  0.0    1428.0      2.0
# 2  2025     1   1135.0  Connecticut   8.0   32.0  0.0  0.0    1345.0      3.0
# 3  2025     1   1126.0      Houston   1.0    2.0  0.0  0.0    1343.0      4.0
# 4  2025     1   1124.0     Iowa St.   3.0   32.0  0.0  0.0    1177.0      5.0
#
#    RANK?
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# Index(['YEAR', 'WEEK', 'TEAM NO', 'TEAM', 'SEED', 'ROUND', 'W', 'L',
#        'AP VOTES', 'AP RANK', 'RANK?'],
#       dtype='object')

# %%
df_2 = pd.read_csv(path + '/Tournament Matchups.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of        YEAR  WEEK  TEAM NO            TEAM  SEED  ROUND    W    L  AP VOTES  \
# 0      2025     1   1123.0          Kansas   7.0   64.0  0.0  0.0    1449.0
# 1      2025     1   1146.0         Alabama   2.0    8.0  0.0  0.0    1428.0
# 2      2025     1   1135.0     Connecticut   8.0   32.0  0.0  0.0    1345.0
# 3      2025     1   1126.0         Houston   1.0    2.0  0.0  0.0    1343.0
# 4      2025     1   1124.0        Iowa St.   3.0   32.0  0.0  0.0    1177.0
# ...     ...   ...      ...             ...   ...    ...  ...  ...       ...
# 15367  2008    20     46.0         Georgia  14.0   64.0  NaN  NaN       2.0
# 15368  2008    20     23.0  Saint Joseph's  11.0   64.0  NaN  NaN       2.0
# 15369  2008    20     59.0       Boise St.  14.0   64.0  NaN  NaN       1.0
# 15370  2008    20     19.0   South Alabama  10.0   64.0  NaN  NaN       1.0
# 15371  2008    20     12.0            UMBC  15.0   64.0  NaN  NaN       1.0
#
#        AP RANK  RANK?
# ...

# %%
print(df_2.columns.tolist())
print(df_2.head(3).to_string())
# Out:
# ['YEAR', 'BY YEAR NO', 'TEAM NO', 'TEAM', 'SEED', 'ROUND', 'CURRENT ROUND', 'SCORE']
#    YEAR  BY YEAR NO  TEAM NO         TEAM  SEED  ROUND  CURRENT ROUND  SCORE
# 0  2025        2140     1141       Auburn     1      4             64     83
# 1  2025        2139     1145  Alabama St.    16     64             64     63
# 2  2025        2138     1119   Louisville     8     64             64     75

# %%
df_bart = pd.read_csv(path + '/KenPom Barttorvik.csv')
print(df_bart.shape)
print(df_bart.columns.tolist())
print(df_bart.head(3).to_string())

df_538 = pd.read_csv(path + '/538 Ratings.csv')
print(df_538.shape)
print(df_538.columns.tolist())
print(df_538.head(3).to_string())
# Out:
# (1147, 103)
# ...

# %%
import pandas as pd
import numpy as np

# ── 1. Load raw files ──────────────────────────────────────────────────────────
df_matchups = pd.read_csv(path + '/Tournament Matchups.csv')
df_bart     = pd.read_csv(path + '/KenPom Barttorvik.csv')
df_538      = pd.read_csv(path + '/538 Ratings.csv')

# ── 2. Pair teams into matchups ────────────────────────────────────────────────
df_matchups = df_matchups.sort_values(['YEAR', 'BY YEAR NO']).reset_index(drop=True)

team_a = df_matchups.iloc[0::2].reset_index(drop=True)
team_b = df_matchups.iloc[1::2].reset_index(drop=True)

games = pd.DataFrame({
    'YEAR'          : team_a['YEAR'],
    'GAME_ID'       : team_a['BY YEAR NO'],
    'CURRENT_ROUND' : team_a['CURRENT ROUND'],
    'TEAM_A'        : team_a['TEAM'],
    'TEAM_A_NO'     : team_a['TEAM NO'],
    'SEED_A'        : team_a['SEED'],
    'SCORE_A'       : team_a['SCORE'],
    'TEAM_B'        : team_b['TEAM'],
    'TEAM_B_NO'     : team_b['TEAM NO'],
    'SEED_B'        : team_b['SEED'],
    'SCORE_B'       : team_b['SCORE'],
})
games['TARGET'] = (games['SCORE_A'] > games['SCORE_B']).astype(int)
print(f"Games built: {len(games)}")

# ── 3. Barttorvik features (drop SEED to avoid collision) ─────────────────────
bart_cols = [
    'YEAR', 'TEAM NO',
    'KADJ EM', 'KADJ O', 'KADJ D',
    'BADJ EM', 'BADJ O', 'BADJ D',
    'BARTHAG', 'EFG%', 'EFG%D',
    'TOV%', 'TOV%D', 'OREB%', 'DREB%',
    'FTR', 'FTRD', 'ELITE SOS', 'WAB',
    'EXP', 'TALENT', 'WIN%',
]
df_bart_slim = df_bart[bart_cols].copy()

# ── 4. Merge Barttorvik onto team A and B ──────────────────────────────────────
games = games.merge(
    df_bart_slim.add_suffix('_A').rename(columns={'YEAR_A':'YEAR', 'TEAM NO_A':'TEAM_A_NO'}),
    on=['YEAR', 'TEAM_A_NO'], how='left'
)
games = games.merge(
    df_bart_slim.add_suffix('_B').rename(columns={'YEAR_B':'YEAR', 'TEAM NO_B':'TEAM_A_NO'}),
    left_on=['YEAR', 'TEAM_B_NO'], right_on=['YEAR', 'TEAM_A_NO'], how='left',
    suffixes=('', '_drop')
)
# Drop the duplicate key col from second merge
games = games.drop(columns=[c for c in games.columns if c.endswith('_drop') or c == 'TEAM_A_NO_y'], errors='ignore')

# ── 5. Merge 538 power rating ──────────────────────────────────────────────────
df_538_slim = df_538[['YEAR', 'TEAM NO', 'POWER RATING']].copy()

games = games.merge(
    df_538_slim.rename(columns={'TEAM NO':'TEAM_A_NO', 'POWER RATING':'POWER_RATING_A'}),
    on=['YEAR', 'TEAM_A_NO'], how='left'
)
games = games.merge(
    df_538_slim.rename(columns={'TEAM NO':'TEAM_B_NO', 'POWER RATING':'POWER_RATING_B'}),
    on=['YEAR', 'TEAM_B_NO'], how='left'
)

# ── 6. Difference features ─────────────────────────────────────────────────────
stat_bases = [
    'KADJ EM', 'KADJ O', 'KADJ D',
    'BADJ EM', 'BADJ O', 'BADJ D',
    'BARTHAG', 'EFG%', 'EFG%D',
    'TOV%', 'TOV%D', 'OREB%', 'DREB%',
    'ELITE SOS', 'WAB', 'WIN%', 'TALENT', 'EXP',
]
for stat in stat_bases:
    a, b = f'{stat}_A', f'{stat}_B'
    if a in games.columns and b in games.columns:
        games[f'{stat}_DIFF'] = games[a] - games[b]

games['SEED_DIFF']         = games['SEED_A'] - games['SEED_B']
games['POWER_RATING_DIFF'] = games['POWER_RATING_A'] - games['POWER_RATING_B']

# ── 7. Quality check ───────────────────────────────────────────────────────────
print(f"Final shape: {games.shape}")
print(f"Years: {sorted(games['YEAR'].unique())}")
print(f"Target distribution:\n{games['TARGET'].value_counts()}")
print(f"\nNull counts (top 10):\n{games.isnull().sum().sort_values(ascending=False).head(10)}")
print(games[['YEAR','TEAM_A','SEED_A','TEAM_B','SEED_B','TARGET',
             'KADJ EM_A','KADJ EM_B','KADJ EM_DIFF']].head(5).to_string())
# Out:
# Games built: 1070
# Final shape: (1070, 74)
# Years: [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2021, 2022, 2023, 2024, 2025]
# Target distribution:
# TARGET
# 0    668
# 1    402
# Name: count, dtype: int64
#
# Null counts (top 10):
# POWER_RATING_DIFF    567
# POWER_RATING_B       567
# POWER_RATING_A       567
# KADJ O_DIFF            0
# WIN%_B                 0
# TALENT_B               0
# EXP_B                  0
# WAB_B                  0
# ELITE SOS_B            0
# FTRD_B                 0
# dtype: int64
#    YEAR   TEAM_A  SEED_A          TEAM_B  SEED_B  TARGET  KADJ EM_A  KADJ EM_B  KADJ EM_DIFF
# 0  2008  Memphis       1          Kansas       1       0    29.3779    33.9647       -4.5868
# 1  2008     UCLA       1         Memphis       1       0    30.5753    29.3779        1.1974
# 2  2008   Kansas       1  North Carolina       1       1    33.9647    28.1446        5.8201
# ...

# %%
# ── 1. Drop 538 (too many nulls) and define feature set ───────────────────────
drop_cols = ['POWER_RATING_A', 'POWER_RATING_B', 'POWER_RATING_DIFF']
games_clean = games.drop(columns=drop_cols)

# Use only DIFF features + seeds for the model
# (raw A/B stats are redundant once we have diffs, and cause data leakage risk)
diff_features = [c for c in games_clean.columns if c.endswith('_DIFF')]
seed_features = ['SEED_A', 'SEED_B', 'SEED_DIFF']
feature_cols  = diff_features + seed_features

X = games_clean[feature_cols]
y = games_clean['TARGET']

print(f"Features: {len(feature_cols)}")
print(feature_cols)

# ── 2. Leave-one-year-out cross validation ────────────────────────────────────
# This is the RIGHT way to validate — never train on the same year you predict
years = sorted(games_clean['YEAR'].unique())
brier_scores = []
accuracies   = []

for test_year in years:
    train_mask = games_clean['YEAR'] != test_year
    test_mask  = games_clean['YEAR'] == test_year

    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]

    rf = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
    rf.fit(X_train, y_train)

    probs  = rf.predict_proba(X_test)[:, 1]
    preds  = rf.predict(X_test)
    brier  = brier_score_loss(y_test, probs)
    acc    = (preds == y_test).mean()

    brier_scores.append(brier)
    accuracies.append(acc)
    print(f"{test_year}  Brier: {brier:.4f}  Accuracy: {acc:.3f}  (n={test_mask.sum()})")

print(f"\nMean Brier: {np.mean(brier_scores):.4f}  (target < 0.20)")
print(f"Mean Accuracy: {np.mean(accuracies):.3f}")

# ── 3. Feature importance (train on all data except 2025) ─────────────────────
train_mask = games_clean['YEAR'] != 2025
rf_full = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
rf_full.fit(X[train_mask], y[train_mask])

importances = pd.Series(rf_full.feature_importances_, index=feature_cols) \
                .sort_values(ascending=False)

print("\nTop 15 features:")
print(importances.head(15))

# ── 4. Plot feature importances ───────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 6))
importances.head(15).plot(kind='barh', ax=ax, color='steelblue')
ax.invert_yaxis()
ax.set_title('Random Forest — Top 15 Feature Importances')
ax.set_xlabel('Importance')
plt.tight_layout()
plt.show()
# Out:
# Features: 22
# ['KADJ EM_DIFF', 'KADJ O_DIFF', 'KADJ D_DIFF', 'BADJ EM_DIFF', 'BADJ O_DIFF', 'BADJ D_DIFF', 'BARTHAG_DIFF', 'EFG%_DIFF', 'EFG%D_DIFF', 'TOV%_DIFF', 'TOV%D_DIFF', 'OREB%_DIFF', 'DREB%_DIFF', 'ELITE SOS_DIFF', 'WAB_DIFF', 'WIN%_DIFF', 'TALENT_DIFF', 'EXP_DIFF', 'SEED_DIFF', 'SEED_A', 'SEED_B', 'SEED_DIFF']
# 2008  Brier: 0.1557  Accuracy: 0.730  (n=63)
# 2009  Brier: 0.1573  Accuracy: 0.794  (n=63)
# 2010  Brier: 0.1920  Accuracy: 0.667  (n=63)
# 2011  Brier: 0.2394  Accuracy: 0.603  (n=63)
# 2012  Brier: 0.1643  Accuracy: 0.714  (n=63)
# 2013  Brier: 0.2129  Accuracy: 0.651  (n=63)
# 2014  Brier: 0.2234  Accuracy: 0.619  (n=63)
# 2015  Brier: 0.1746  Accuracy: 0.762  (n=63)
# 2016  Brier: 0.1892  Accuracy: 0.730  (n=63)
# 2017  Brier: 0.1713  Accuracy: 0.730  (n=63)
# 2018  Brier: 0.2214  Accuracy: 0.651  (n=63)
# 2019  Brier: 0.1872  Accuracy: 0.667  (n=63)
# 2021  Brier: 0.2171  Accuracy: 0.677  (n=62)
# 2022  Brier: 0.2031  Accuracy: 0.698  (n=63)
# ...

# %%
top_features = [
    'BADJ EM_DIFF', 'KADJ EM_DIFF', 'BARTHAG_DIFF', 'WAB_DIFF',
    'TALENT_DIFF', 'KADJ O_DIFF', 'KADJ D_DIFF', 'EXP_DIFF',
    'BADJ O_DIFF', 'BADJ D_DIFF', 'TOV%D_DIFF', 'EFG%D_DIFF',
    'DREB%_DIFF', 'WIN%_DIFF', 'SEED_DIFF'
]
X_top = games_clean[top_features]
y     = games_clean['TARGET']

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.calibration import calibration_curve
from sklearn.metrics import brier_score_loss

years = sorted(games_clean['YEAR'].unique())
gbm_brier = []
gbm_acc   = []
rf_brier  = []

for test_year in years:
    train_mask = games_clean['YEAR'] != test_year
    test_mask  = games_clean['YEAR'] == test_year

    X_train, X_test = X_top[train_mask], X_top[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]

    gbm = GradientBoostingClassifier(
        n_estimators=500, max_depth=4,
        learning_rate=0.05, subsample=0.8,
        random_state=42
    )
    gbm.fit(X_train, y_train)
    gbm_probs = gbm.predict_proba(X_test)[:, 1]
    gbm_preds = gbm.predict(X_test)
    gbm_brier.append(brier_score_loss(y_test, gbm_probs))
    gbm_acc.append((gbm_preds == y_test).mean())

    rf = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
    rf.fit(X_train, y_train)
    rf_brier.append(brier_score_loss(y_test, rf.predict_proba(X_test)[:, 1]))

    print(f"{test_year}  GBM Brier: {gbm_brier[-1]:.4f}  RF Brier: {rf_brier[-1]:.4f}  Acc: {gbm_acc[-1]:.3f}")

print(f"\nMean GBM Brier: {np.mean(gbm_brier):.4f}")
print(f"Mean RF Brier:  {np.mean(rf_brier):.4f}")
# Out:
# 2008  GBM Brier: 0.1723  RF Brier: 0.1527  Acc: 0.730
# 2009  GBM Brier: 0.1580  RF Brier: 0.1593  Acc: 0.762
# 2010  GBM Brier: 0.2283  RF Brier: 0.1941  Acc: 0.667
# 2011  GBM Brier: 0.2971  RF Brier: 0.2479  Acc: 0.619
# 2012  GBM Brier: 0.1708  RF Brier: 0.1642  Acc: 0.778
# 2013  GBM Brier: 0.2495  RF Brier: 0.2112  Acc: 0.619
# 2014  GBM Brier: 0.3117  RF Brier: 0.2298  Acc: 0.571
# 2015  GBM Brier: 0.1905  RF Brier: 0.1665  Acc: 0.746
# 2016  GBM Brier: 0.1828  RF Brier: 0.1802  Acc: 0.762
# 2017  GBM Brier: 0.1833  RF Brier: 0.1743  Acc: 0.746
# 2018  GBM Brier: 0.2491  RF Brier: 0.2254  Acc: 0.651
# 2019  GBM Brier: 0.2122  RF Brier: 0.1838  Acc: 0.667
# 2021  GBM Brier: 0.2365  RF Brier: 0.2109  Acc: 0.694
# 2022  GBM Brier: 0.2295  RF Brier: 0.2074  Acc: 0.683
# 2023  GBM Brier: 0.2780  RF Brier: 0.2132  Acc: 0.619
# 2024  GBM Brier: 0.2091  RF Brier: 0.1874  Acc: 0.698
# 2025  GBM Brier: 0.1788  RF Brier: 0.1502  Acc: 0.746
#
# Mean GBM Brier: 0.2199
# ...

# %%
from sklearn.calibration import CalibratedClassifierCV, calibration_curve
import matplotlib.pyplot as plt

years = sorted(games_clean['YEAR'].unique())
rf_cal_brier  = []
rf_raw_brier  = []

for test_year in years:
    train_mask = games_clean['YEAR'] != test_year
    test_mask  = games_clean['YEAR'] == test_year

    X_train, X_test = X_top[train_mask], X_top[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]

    # Raw RF
    rf = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
    rf.fit(X_train, y_train)
    raw_probs = rf.predict_proba(X_test)[:, 1]
    rf_raw_brier.append(brier_score_loss(y_test, raw_probs))

    # Calibrated RF (Platt scaling via sigmoid)
    rf_cal = CalibratedClassifierCV(
        RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1),
        method='sigmoid', cv=5
    )
    rf_cal.fit(X_train, y_train)
    cal_probs = rf_cal.predict_proba(X_test)[:, 1]
    rf_cal_brier.append(brier_score_loss(y_test, cal_probs))

    print(f"{test_year}  Raw RF: {rf_raw_brier[-1]:.4f}  Calibrated RF: {rf_cal_brier[-1]:.4f}")

print(f"\nMean Raw RF Brier:        {np.mean(rf_raw_brier):.4f}")
print(f"Mean Calibrated RF Brier: {np.mean(rf_cal_brier):.4f}")

# ── Calibration curve on 2025 holdout ─────────────────────────────────────────
train_mask = games_clean['YEAR'] != 2025
test_mask  = games_clean['YEAR'] == 2025

rf_cal_final = CalibratedClassifierCV(
    RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1),
    method='sigmoid', cv=5
)
rf_cal_final.fit(X_top[train_mask], y[train_mask])
probs_2025 = rf_cal_final.predict_proba(X_top[test_mask])[:, 1]

frac_pos, mean_pred = calibration_curve(y[test_mask], probs_2025, n_bins=8)
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(mean_pred, frac_pos, 's-', label='Calibrated RF')
ax.plot([0,1],[0,1],'k--', label='Perfect')
ax.set_xlabel('Mean predicted probability')
ax.set_ylabel('Fraction of positives')
ax.set_title('Calibration curve — 2025 holdout')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# 2008  Raw RF: 0.1527  Calibrated RF: 0.1542
# 2009  Raw RF: 0.1593  Calibrated RF: 0.1660
# 2010  Raw RF: 0.1941  Calibrated RF: 0.1945
# 2011  Raw RF: 0.2479  Calibrated RF: 0.2376
# 2012  Raw RF: 0.1642  Calibrated RF: 0.1696
# 2013  Raw RF: 0.2112  Calibrated RF: 0.2095
# 2014  Raw RF: 0.2298  Calibrated RF: 0.2231
# 2015  Raw RF: 0.1665  Calibrated RF: 0.1635
# 2016  Raw RF: 0.1802  Calibrated RF: 0.1796
# 2017  Raw RF: 0.1743  Calibrated RF: 0.1781
# 2018  Raw RF: 0.2254  Calibrated RF: 0.2183
# 2019  Raw RF: 0.1838  Calibrated RF: 0.1940
# 2021  Raw RF: 0.2109  Calibrated RF: 0.2096
# 2022  Raw RF: 0.2074  Calibrated RF: 0.2072
# 2023  Raw RF: 0.2132  Calibrated RF: 0.2127
# 2024  Raw RF: 0.1874  Calibrated RF: 0.1853
# 2025  Raw RF: 0.1502  Calibrated RF: 0.1546
#
# Mean Raw RF Brier:        0.1917
# Mean Calibrated RF Brier: 0.1916

# %%
# Check what 2025 data looks like in our dataset
games_2025 = games_clean[games_clean['YEAR'] == 2025].copy()
print(f"2025 games in dataset: {len(games_2025)}")
print(games_2025[['TEAM_A','SEED_A','TEAM_B','SEED_B','CURRENT_ROUND','TARGET']].to_string())
# Out:
# 2025 games in dataset: 63
#                 TEAM_A  SEED_A           TEAM_B  SEED_B  CURRENT_ROUND  TARGET
# 1007           Houston       1          Florida       1              2       0
# 1008           Houston       1             Duke       1              4       1
# 1009           Florida       1           Auburn       1              4       1
# 1010         Tennessee       2          Houston       1              8       0
# 1011           Alabama       2             Duke       1              8       0
# 1012        Texas Tech       3          Florida       1              8       0
# 1013      Michigan St.       2           Auburn       1              8       0
# 1014         Tennessee       2         Kentucky       3             16       1
# 1015            Purdue       4          Houston       1             16       0
# 1016           Alabama       2              BYU       6             16       1
# 1017           Arizona       4             Duke       1             16       0
# ...

# %%
# ── 1. Train final model on 2008-2024 ─────────────────────────────────────────
train_mask = games_clean['YEAR'] != 2025
test_mask  = games_clean['YEAR'] == 2025

rf_final = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
rf_final.fit(X_top[train_mask], y[train_mask])

# ── 2. Predict 2025 ────────────────────────────────────────────────────────────
probs_2025 = rf_final.predict_proba(X_top[test_mask])[:, 1]
preds_2025 = rf_final.predict(X_top[test_mask])

results_2025 = games_2025[['CURRENT_ROUND','TEAM_A','SEED_A','TEAM_B','SEED_B','TARGET']].copy()
results_2025['PRED_PROB_A']  = probs_2025.round(3)
results_2025['PREDICTED_WIN'] = preds_2025
results_2025['CORRECT']       = (preds_2025 == results_2025['TARGET']).astype(int)
results_2025['ROUND_NAME'] = results_2025['CURRENT_ROUND'].map({
    64: 'Round of 64', 32: 'Round of 32',
    16: 'Sweet 16', 8: 'Elite 8', 4: 'Final Four', 2: 'Championship'
})

# ── 3. Summary by round ────────────────────────────────────────────────────────
print("=== Accuracy by Round ===")
round_order = ['Round of 64','Round of 32','Sweet 16','Elite 8','Final Four','Championship']
for rnd in round_order:
    subset = results_2025[results_2025['ROUND_NAME'] == rnd]
    if len(subset) == 0:
        continue
    acc = subset['CORRECT'].mean()
    print(f"{rnd:20s}  {subset['CORRECT'].sum()}/{len(subset)}  ({acc:.1%})")

brier_2025 = brier_score_loss(results_2025['TARGET'], probs_2025)
print(f"\n2025 Brier Score: {brier_2025:.4f}")
print(f"2025 Overall Accuracy: {results_2025['CORRECT'].mean():.1%}")

# ── 4. Print upsets we got wrong and right ────────────────────────────────────
print("\n=== Upsets (higher seed won) ===")
upsets = results_2025[results_2025['TARGET'] == 0].copy()  # team B won
upsets['MODEL_CAUGHT'] = (upsets['PREDICTED_WIN'] == 0).astype(int)
print(upsets[['ROUND_NAME','TEAM_A','SEED_A','TEAM_B','SEED_B',
              'PRED_PROB_A','MODEL_CAUGHT']].to_string())

# ── 5. Full results sorted by round ───────────────────────────────────────────
print("\n=== Full 2025 Predictions vs Actuals ===")
print(results_2025.sort_values('CURRENT_ROUND', ascending=False)[
    ['ROUND_NAME','TEAM_A','SEED_A','TEAM_B','SEED_B',
     'PRED_PROB_A','TARGET','CORRECT']
].to_string())
# Out:
# === Accuracy by Round ===
# Round of 64           26/32  (81.2%)
# Round of 32           12/16  (75.0%)
# Sweet 16              7/8  (87.5%)
# Elite 8               4/4  (100.0%)
# Final Four            0/2  (0.0%)
# Championship          0/1  (0.0%)
#
# 2025 Brier Score: 0.1502
# 2025 Overall Accuracy: 77.8%
#
# === Upsets (higher seed won) ===
#         ROUND_NAME            TEAM_A  SEED_A        TEAM_B  SEED_B  PRED_PROB_A  MODEL_CAUGHT
# 1007  Championship           Houston       1       Florida       1        0.638             0
# 1010       Elite 8         Tennessee       2       Houston       1        0.364             1
# 1011       Elite 8           Alabama       2          Duke       1        0.324             1
# 1012       Elite 8        Texas Tech       3       Florida       1        0.316             1
# 1013       Elite 8      Michigan St.       2        Auburn       1        0.458             1
# ...

# %%
# ── Final model summary + save everything ─────────────────────────────────────
import pickle

# Save the trained model and feature list
with open('rf_march_madness_final.pkl', 'wb') as f:
    pickle.dump({'model': rf_final, 'features': top_features}, f)

# ── Pretty summary table ───────────────────────────────────────────────────────
print("=" * 55)
print("  MARCH MADNESS MODEL — FINAL RESULTS SUMMARY")
print("=" * 55)
print(f"\n  Model:         Random Forest (500 trees)")
print(f"  Training data: 2008–2024 ({train_mask.sum()} games)")
print(f"  Features:      {len(top_features)} efficiency diff features")
print(f"\n  ── Cross-validated performance (2008–2025) ──")
print(f"  Mean Brier Score:  0.1917  (target < 0.20) ✓")
print(f"  Mean Accuracy:     69.4%")
print(f"\n  ── 2025 holdout performance ──")
print(f"  Brier Score:  {brier_2025:.4f}  ✓")
print(f"  Accuracy:     {results_2025['CORRECT'].mean():.1%}")

print(f"\n  ── 2025 accuracy by round ──")
for rnd in round_order:
    subset = results_2025[results_2025['ROUND_NAME'] == rnd]
    if len(subset) == 0: continue
    acc = subset['CORRECT'].mean()
    bar = '█' * int(acc * 20)
    print(f"  {rnd:20s} {subset['CORRECT'].sum()}/{len(subset)}  {bar} {acc:.0%}")

print(f"\n  Top predictors:")
for feat, imp in importances.head(5).items():
    print(f"    {feat:20s}  {imp:.4f}")
print("=" * 55)

# ── Worst misses (games we were most wrong about) ─────────────────────────────
results_2025['ERROR'] = abs(results_2025['PRED_PROB_A'] - results_2025['TARGET'])
print("\nTop 5 worst predictions:")
print(results_2025.nlargest(5, 'ERROR')[
    ['ROUND_NAME','TEAM_A','SEED_A','TEAM_B','SEED_B','PRED_PROB_A','TARGET']
].to_string())
# Out:
# ...
#   MARCH MADNESS MODEL — FINAL RESULTS SUMMARY
# ...
#
#   Model:         Random Forest (500 trees)
#   Training data: 2008–2024 (1007 games)
#   Features:      15 efficiency diff features
#
#   ── Cross-validated performance (2008–2025) ──
#   Mean Brier Score:  0.1917  (target < 0.20) ✓
#   Mean Accuracy:     69.4%
#
#   ── 2025 holdout performance ──
#   Brier Score:  0.1502  ✓
#   Accuracy:     77.8%
#
#   ── 2025 accuracy by round ──
#   Round of 64          26/32  ████████████████ 81%
#   Round of 32          12/16  ███████████████ 75%
#   Sweet 16             7/8  █████████████████ 88%
#   Elite 8              4/4  ████████████████████ 100%
#   Final Four           0/2   0%
#   Championship         0/1   0%
#
#   Top predictors:
#     BADJ EM_DIFF          0.0758
#     WAB_DIFF              0.0734
#     KADJ EM_DIFF          0.0701
#     BARTHAG_DIFF          0.0627
#     TALENT_DIFF           0.0531
# ...
#
# Top 5 worst predictions:
# ...

# %%
import pickle

with open('rf_march_madness_2026.pkl', 'wb') as f:
    pickle.dump({
        'model'   : rf_final,
        'features': top_features
    }, f)

games_clean.to_csv('games_clean_2026.csv', index=False)

print("Model saved — ready for 2026 bracket!")
print(f"Features used: {top_features}")
print(f"Expected Brier score: ~0.19")
# Out:
# Model saved — ready for 2026 bracket!
# Features used: ['BADJ EM_DIFF', 'KADJ EM_DIFF', 'BARTHAG_DIFF', 'WAB_DIFF', 'TALENT_DIFF', 'KADJ O_DIFF', 'KADJ D_DIFF', 'EXP_DIFF', 'BADJ O_DIFF', 'BADJ D_DIFF', 'TOV%D_DIFF', 'EFG%D_DIFF', 'DREB%_DIFF', 'WIN%_DIFF', 'SEED_DIFF']
# Expected Brier score: ~0.19

# %%
# 2026 Barttorvik stats extracted from PDF
# Columns: TEAM, ADJOE, ADJDE, BARTHAG, EFG%, EFG%D, TOV%, TOV%D, OREB%, DREB%, FTR, FTRD, WAB
data_2026 = [
    ['Duke', 128.1, 90.8, .9813, 56.8, 46.2, 15.7, 18.1, 38.1, 75.2, 37.8, 23.7, 13.7],
    ['Michigan', 127.6, 91.0, .9799, 58.1, 44.7, 16.7, 15.5, 35.4, 72.3, 37.7, 26.3, 14.0],
    ['Arizona', 126.9, 91.4, .9776, 55.1, 45.0, 15.1, 16.7, 38.1, 73.1, 42.9, 27.7, 13.7],
    ['Florida', 126.1, 92.3, .9732, 53.5, 46.3, 16.5, 15.4, 43.2, 75.2, 39.1, 34.0, 8.5],
    ['Houston', 125.4, 92.4, .9710, 52.1, 46.6, 13.0, 21.0, 35.9, 69.1, 26.9, 39.0, 9.0],
    ['Illinois', 131.9, 98.2, .9676, 55.1, 47.6, 13.2, 11.6, 38.7, 73.0, 32.9, 20.6, 6.6],
    ['Iowa St.', 123.8, 92.6, .9656, 56.5, 49.5, 15.1, 22.4, 35.3, 71.9, 34.0, 27.9, 7.4],
    ['Purdue', 133.3, 100.2, .9636, 57.6, 52.3, 13.5, 15.6, 36.3, 73.6, 28.6, 26.0, 9.2],
    ['Connecticut', 123.1, 95.0, .9518, 55.3, 45.7, 16.8, 18.0, 35.7, 71.3, 30.0, 40.2, 8.8],
    ['Vanderbilt', 127.4, 99.3, .9462, 55.3, 48.8, 13.3, 17.9, 31.2, 68.4, 38.2, 41.0, 7.3],
    ['Gonzaga', 120.3, 94.0, .9445, 56.3, 46.2, 13.7, 20.5, 34.8, 74.1, 31.1, 31.0, 7.4],
    ['Texas Tech', 126.3, 98.8, .9440, 56.2, 49.4, 15.9, 14.7, 33.3, 69.9, 27.1, 31.6, 5.0],
    ['Michigan St.', 122.9, 96.1, .9438, 53.6, 48.6, 17.1, 14.8, 38.5, 77.4, 36.2, 30.9, 7.4],
    ['Virginia', 122.2, 95.8, .9427, 54.6, 45.3, 16.0, 15.6, 37.9, 70.8, 33.0, 33.0, 7.8],
    ['Idaho', 108.8, 106.2, .5702, 51.9, 50.3, 15.0, 15.2, 28.9, 75.8, 34.8, 39.2, -8.9],
    ['Troy', 110.7, 109.0, .5437, 51.9, 50.1, 17.0, 16.9, 34.8, 68.4, 36.3, 32.1, -6.2],
    ['Penn', 106.6, 105.4, .5314, 50.3, 51.7, 15.4, 17.8, 30.3, 69.5, 35.2, 27.5, -6.0],
    ['Miami FL', 121.1, 101.5, .8842, 55.6, 51.7, 16.2, 18.4, 37.0, 73.7, 37.5, 29.0, 3.8],
    ['Villanova', 119.6, 100.5, .8806, 53.7, 51.3, 15.1, 18.7, 32.4, 68.3, 31.3, 28.9, 3.9],
    ['Saint Louis', 119.6, 102.2, .8584, 59.7, 44.8, 17.4, 16.1, 31.1, 73.0, 34.7, 37.2, 1.9],
    ['Hawaii', 106.9, 101.8, .6358, 52.0, 46.4, 18.9, 16.9, 31.4, 75.0, 42.4, 36.1, -3.7],
    ['TEX/NCST', 124.1, 104.6, .8766, 55.3, 53.0, 13.1, 18.2, 28.5, 69.7, 35.2, 36.5, 0.34],
]

cols = ['TEAM','KADJ O','KADJ D','BARTHAG','EFG%','EFG%D','TOV%','TOV%D','OREB%','DREB%','FTR','FTRD','WAB']
df_2026 = pd.DataFrame(data_2026, columns=cols)

# Add derived features to match training data
df_2026['KADJ EM'] = df_2026['KADJ O'] - df_2026['KADJ D']
df_2026['BADJ EM'] = df_2026['KADJ EM']  # use as proxy
df_2026['BADJ O']  = df_2026['KADJ O']
df_2026['BADJ D']  = df_2026['KADJ D']
df_2026['ELITE SOS'] = 0  # not in PDF, will use 0
df_2026['TALENT']    = 0  # not in PDF, will use 0
df_2026['EXP']       = 0  # not in PDF, will use 0
df_2026['WIN%']      = 0  # not in PDF, will use 0

print(f"Teams loaded: {len(df_2026)}")
print(df_2026[['TEAM','KADJ EM','BARTHAG','WAB']].head(10))
# Out:
# Teams loaded: 67
#           TEAM  KADJ EM  BARTHAG   WAB
# 0         Duke     37.3   0.9813  13.7
# 1     Michigan     36.6   0.9799  14.0
# 2      Arizona     35.5   0.9776  13.7
# 3      Florida     33.8   0.9732   8.5
# 4      Houston     33.0   0.9710   9.0
# 5     Illinois     33.7   0.9676   6.6
# 6     Iowa St.     31.2   0.9656   7.4
# 7       Purdue     33.1   0.9636   9.2
# 8  Connecticut     28.1   0.9518   8.8
# 9   Vanderbilt     28.1   0.9462   7.3

# %%
bracket_teams = [t for region in bracket_2026.values() for s,t in region]
for team in bracket_teams:
    match = df_2026[df_2026['TEAM'] == team]
    if len(match) == 0:
        print(f"MISSING: {team}")

# %%
# Add missing teams
missing = [
    # TEAM, KADJ O, KADJ D, BARTHAG, EFG%, EFG%D, TOV%, TOV%D, OREB%, DREB%, FTR, FTRD, WAB
    ['UConn',     123.1, 95.0, .9518, 55.3, 45.7, 16.8, 18.0, 35.7, 71.3, 30.0, 40.2, 8.8],
    ['SMU',       123.0, 105.0, .8615, 55.7, 51.4, 15.9, 17.1, 35.4, 68.4, 30.6, 32.0, -0.03],
]

cols = ['TEAM','KADJ O','KADJ D','BARTHAG','EFG%','EFG%D','TOV%','TOV%D','OREB%','DREB%','FTR','FTRD','WAB']
df_missing = pd.DataFrame(missing, columns=cols)
df_missing['KADJ EM'] = df_missing['KADJ O'] - df_missing['KADJ D']
df_missing['BADJ EM'] = df_missing['KADJ EM']
df_missing['BADJ O']  = df_missing['KADJ O']
df_missing['BADJ D']  = df_missing['KADJ D']
df_missing['ELITE SOS'] = 0
df_missing['TALENT']    = 0
df_missing['EXP']       = 0
df_missing['WIN%']      = 0

df_2026 = pd.concat([df_2026, df_missing], ignore_index=True)
print(f"Total teams: {len(df_2026)}")

# Verify
for team in ['UConn', 'SMU']:
    row = df_2026[df_2026['TEAM'] == team]
    print(f"{team}: KADJ EM = {row['KADJ EM'].values[0]:.1f}")
# Out:
# Total teams: 69
# UConn: KADJ EM = 28.1
# SMU: KADJ EM = 18.0

# %%
df_2026 = df_2026.drop_duplicates(subset='TEAM', keep='first').reset_index(drop=True)
print(f"Total teams after dedup: {len(df_2026)}")
# Out:
# Total teams after dedup: 68

# %%
# Rebuild df_2026 with ALL features from the PDF
# Adding ELITE SOS, WAB, EXP, TALENT, WIN% from the PDF
# Format: TEAM, KADJ O, KADJ D, BARTHAG, EFG%, EFG%D, TOV%, TOV%D, OREB%, DREB%, FTR, FTRD, WAB, ELITE SOS, WIN%
# EXP and TALENT are NOT in this PDF — those come from a different Barttorvik page

# What IS in the PDF that we zeroed out:
# WIN% — we can calculate from the record (W/G)
data_2026_full = [
    # TEAM,          KADJ O, KADJ D,  BARTHAG, EFG%, EFG%D, TOV%, TOV%D,OREB%,DREB%, FTR,  FTRD,  WAB,   WIN%
    ['Duke',          128.1,  90.8,  .9813, 56.8, 46.2, 15.7, 18.1, 38.1, 75.2, 37.8, 23.7, 13.7, 32/34],
    ['Michigan',      127.6,  91.0,  .9799, 58.1, 44.7, 16.7, 15.5, 35.4, 72.3, 37.7, 26.3, 14.0, 31/34],
    ['Arizona',       126.9,  91.4,  .9776, 55.1, 45.0, 15.1, 16.7, 38.1, 73.1, 42.9, 27.7, 13.7, 32/34],
    ['Florida',       126.1,  92.3,  .9732, 53.5, 46.3, 16.5, 15.4, 43.2, 75.2, 39.1, 34.0,  8.5, 26/33],
    ['Houston',       125.4,  92.4,  .9710, 52.1, 46.6, 13.0, 21.0, 35.9, 69.1, 26.9, 39.0,  9.0, 28/34],
    ['Illinois',      131.9,  98.2,  .9676, 55.1, 47.6, 13.2, 11.6, 38.7, 73.0, 32.9, 20.6,  6.6, 24/32],
    ['Iowa St.',      123.8,  92.6,  .9656, 56.5, 49.5, 15.1, 22.4, 35.3, 71.9, 34.0, 27.9,  7.4, 27/34],
    ['Purdue',        133.3, 100.2,  .9636, 57.6, 52.3, 13.5, 15.6, 36.3, 73.6, 28.6, 26.0,  9.2, 27/35],
    ['Connecticut',   123.1,  95.0,  .9518, 55.3, 45.7, 16.8, 18.0, 35.7, 71.3, 30.0, 40.2,  8.8, 29/34],
    ['UCF',           120.0, 105.7,  .8120, 52.8, 52.4, 15.7, 15.8, 34.4, 71.5, 30.8, 35.2,  2.1, 21/32],
    ['Kennesaw St.',  110.8, 109.5,  .5338, 50.7, 48.5, 16.7, 16.1, 35.5, 68.7, 45.1, 47.5, -8.0, 21/34],
    ['LIU',           103.6, 109.7,  .3409, 53.3, 49.8, 19.0, 18.9, 34.3, 67.4, 34.7, 34.1, -5.8, 24/34],
    ['Siena',         107.2, 108.9,  .4548, 50.6, 48.6, 16.0, 17.1, 31.9, 71.0, 34.2, 27.2, -7.8, 23/34],
    ['UMBC',          107.6, 109.2,  .4555, 53.9, 49.2, 14.1, 15.2, 25.1, 74.4, 33.8, 33.8, -5.1, 24/32],
    ['Howard',        103.4, 106.2,  .4240, 50.6, 47.4, 19.8, 21.3, 36.6, 68.0, 44.2, 38.3, -6.9, 23/33],
    ['Prairie View',  101.4, 111.4,  .2536, 47.9, 50.4, 16.0, 19.1, 27.1, 65.2, 42.8, 43.9,-12.6, 18/35],
    ['Lehigh',        102.6, 112.8,  .2516, 53.3, 50.6, 17.5, 16.3, 22.8, 68.3, 32.2, 32.8,-12.0, 18/34],
    ['Idaho',         108.8, 106.2,  .5702, 51.9, 50.3, 15.0, 15.2, 28.9, 75.8, 34.8, 39.2, -8.9, 21/35],
    ['Troy',          110.7, 109.0,  .5437, 51.9, 50.1, 17.0, 16.9, 34.8, 68.4, 36.3, 32.1, -6.2, 22/33],
    ['Penn',          106.6, 105.4,  .5314, 50.3, 51.7, 15.4, 17.8, 30.3, 69.5, 35.2, 27.5, -6.0, 18/29],
    ['Miami FL',      121.1, 101.5,  .8842, 55.6, 51.7, 16.2, 18.4, 37.0, 73.7, 37.5, 29.0,  3.8, 25/33],
    ['Villanova',     119.6, 100.5,  .8806, 53.7, 51.3, 15.1, 18.7, 32.4, 68.3, 31.3, 28.9,  3.9, 24/32],
    ['Saint Louis',   119.6, 102.2,  .8584, 59.7, 44.8, 17.4, 16.1, 31.1, 73.0, 34.7, 37.2,  1.9, 28/33],
    ['Hawaii',        106.9, 101.8,  .6358, 52.0, 46.4, 18.9, 16.9, 31.4, 75.0, 42.4, 36.1, -3.7, 24/32],
    ['TEX/NCST',      124.1, 104.6,  .8766, 55.3, 53.0, 13.1, 18.2, 28.5, 69.7, 35.2, 36.5,  0.34,20/33],
    ['UConn',         123.1,  95.0,  .9518, 55.3, 45.7, 16.8, 18.0, 35.7, 71.3, 30.0, 40.2,  8.8, 29/34],
    ['SMU',           123.0, 105.0,  .8615, 55.7, 51.4, 15.9, 17.1, 35.4, 68.4, 30.6, 32.0, -0.03,20/33],
]

cols = ['TEAM','KADJ O','KADJ D','BARTHAG','EFG%','EFG%D','TOV%','TOV%D',
        'OREB%','DREB%','FTR','FTRD','WAB','WIN%']
df_2026 = pd.DataFrame(data_2026_full, columns=cols)
df_2026['KADJ EM'] = df_2026['KADJ O'] - df_2026['KADJ D']
df_2026['BADJ EM'] = df_2026['KADJ EM']
df_2026['BADJ O']  = df_2026['KADJ O']
df_2026['BADJ D']  = df_2026['KADJ D']
df_2026['ELITE SOS'] = 0  # still not in PDF
df_2026['TALENT']    = 0  # not in this PDF page
df_2026['EXP']       = 0  # not in this PDF page

df_2026 = df_2026.drop_duplicates(subset='TEAM', keep='first').reset_index(drop=True)
print(f"Total teams: {len(df_2026)}")
print("WIN% sample:")
print(df_2026[['TEAM','KADJ EM','WIN%','WAB']].head(5))
# Out:
# Total teams: 68
# WIN% sample:
#        TEAM  KADJ EM      WIN%   WAB
# 0      Duke     37.3  0.941176  13.7
# 1  Michigan     36.6  0.911765  14.0
# 2   Arizona     35.5  0.941176  13.7
# 3   Florida     33.8  0.787879   8.5
# 4   Houston     33.0  0.823529   9.0

# %%
# EXP and TALENT from Barttorvik team tables
exp_talent = {
    'Duke':          (0.856, 91.161),
    'Michigan':      (1.947, 69.852),
    'Arizona':       (1.406, 73.506),
    'Florida':       (1.928, 41.689),
    'Houston':       (1.553, 81.968),
    'Illinois':      (1.548, 63.056),
    'Iowa St.':      (1.944, 50.469),
    'Purdue':        (2.015, 59.300),
    'Connecticut':   (1.997, 84.266),
    'Vanderbilt':    (2.308, 35.964),
    'Gonzaga':       (2.110, 36.781),
    'Texas Tech':    (1.601, 41.675),
    'Michigan St.':  (1.815, 68.794),
    'Virginia':      (1.724, 53.814),
    'St. John\'s':   (2.300, 70.084),
    'Tennessee':     (1.473, 59.748),
    'Louisville':    (2.208, 39.120),
    'Alabama':       (1.526, 73.555),
    'Arkansas':      (1.457, 80.525),
    'Nebraska':      (2.260, 42.458),
    'Wisconsin':     (1.871, 38.623),
    'Kansas':        (1.629, 57.848),
    'Ohio St.':      (1.779, 68.946),
    'UCLA':          (2.244, 70.281),
    'Saint Mary\'s': (1.349, 36.989),
    'Iowa':          (1.776, 14.299),
    'North Carolina':(1.523, 63.835),
    'Utah St.':      (2.185, 26.458),
    'Clemson':       (2.344, 43.890),
    'Kentucky':      (1.581, 85.092),
    'BYU':           (1.463, 48.949),
    'Georgia':       (1.553, 61.020),
    'N.C. State':    (2.189, 63.205),
    'Texas A&M':     (2.497, 29.541),
    'Missouri':      (2.282, 66.401),
    'VCU':           (1.703, 21.117),
    'TCU':           (1.807, 50.351),
    'South Florida': (2.247, 30.828),
    'Santa Clara':   (1.435, 20.016),
    'McNeese':       (1.919, 48.482),
    'High Point':    (2.541, 13.909),
    'Akron':         (2.447, 12.800),
    'Hofstra':       (1.895,  0.200),
    'Tennessee St.': (2.506,  3.291),
    'Wright St.':    (1.245,  0.200),
    'Queens':        (1.734,  9.008),
    'Furman':        (1.607, 11.546),
    'N. Iowa':       (2.321, 19.874),
    'N. Dakota St.': (1.834,  0.200),
    'Cal Baptist':   (2.169,  1.476),
    'UCF':           (2.429, 42.096),
    'Kennesaw St.':  (1.297, 13.242),
    'LIU':           (2.414,  0.200),
    'Siena':         (1.725,  3.878),
    'UMBC':          (2.082,  7.798),
    'Howard':        (1.890,  0.200),
    'Prairie View':  (2.802,  0.231),
    'Lehigh':        (1.368,  0.826),
    'Idaho':         (2.008,  0.200),
    'Troy':          (1.897,  0.200),
    'Penn':          (1.869, 17.192),
    'Miami FL':      (1.670, 80.783),
    'Villanova':     (1.548, 63.750),
    'Saint Louis':   (1.939, 21.913),
    'Hawaii':        (2.599,  9.248),
    'TEX/NCST':      (2.189, 63.205),
    'UConn':         (1.997, 84.266),
    'SMU':           (2.034, 44.289),
}

# Update df_2026 with real EXP and TALENT
for team, (exp, talent) in exp_talent.items():
    mask = df_2026['TEAM'] == team
    if mask.sum() > 0:
        df_2026.loc[mask, 'EXP']    = exp
        df_2026.loc[mask, 'TALENT'] = talent

print("Updated EXP and TALENT for all tournament teams")
print(df_2026[['TEAM','KADJ EM','EXP','TALENT']].head(10))
# Out:
# Updated EXP and TALENT for all tournament teams
#           TEAM  KADJ EM    EXP  TALENT
# 0         Duke     37.3  0.856  91.161
# 1     Michigan     36.6  1.947  69.852
# 2      Arizona     35.5  1.406  73.506
# 3      Florida     33.8  1.928  41.689
# 4      Houston     33.0  1.553  81.968
# 5     Illinois     33.7  1.548  63.056
# 6     Iowa St.     31.2  1.944  50.469
# 7       Purdue     33.1  2.015  59.300
# 8  Connecticut     28.1  1.997  84.266
# 9   Vanderbilt     28.1  2.308  35.964
# /var/folders/2t/8ngz9d_124l6skbswcnmqd1h0000gn/T/ipykernel_77308/645022418.py:77: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.856' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_2026.loc[mask, 'EXP']    = exp
# ...

# %%
# ── 2026 Bracket definition ────────────────────────────────────────────────────
bracket_2026 = {
    'East': [
        (1,'Duke'),        (16,'Siena'),
        (8,'Ohio St.'),    (9,'TCU'),
        (5,'St. John\'s'), (12,'N. Iowa'),
        (4,'Kansas'),      (13,'Cal Baptist'),
        (6,'Louisville'),  (11,'South Florida'),
        (3,'Michigan St.'),(14,'N. Dakota St.'),
        (7,'UCLA'),        (10,'UCF'),
        (2,'UConn'),       (15,'Furman'),
    ],
    'South': [
        (1,'Florida'),     (16,'Lehigh'),
        (8,'Clemson'),     (9,'Iowa'),
        (5,'Vanderbilt'),  (12,'McNeese'),
        (4,'Nebraska'),    (13,'Troy'),
        (6,'North Carolina'),(11,'VCU'),
        (3,'Illinois'),    (14,'Penn'),
        (7,'Saint Mary\'s'),(10,'Texas A&M'),
        (2,'Houston'),     (15,'Idaho'),
    ],
    'West': [
        (1,'Arizona'),     (16,'LIU'),
        (8,'Villanova'),   (9,'Utah St.'),
        (5,'Wisconsin'),   (12,'High Point'),
        (4,'Arkansas'),    (13,'Hawaii'),
        (6,'BYU'),         (11,'TEX/NCST'),
        (3,'Gonzaga'),     (14,'Kennesaw St.'),
        (7,'Miami FL'),    (10,'Missouri'),
        (2,'Purdue'),      (15,'Queens'),
    ],
    'Midwest': [
        (1,'Michigan'),    (16,'UMBC'),
        (8,'Georgia'),     (9,'Saint Louis'),
        (5,'Texas Tech'),  (12,'Akron'),
        (4,'Alabama'),     (13,'Hofstra'),
        (6,'Tennessee'),   (11,'SMU'),
        (3,'Virginia'),    (14,'Wright St.'),
        (7,'Kentucky'),    (10,'Santa Clara'),
        (2,'Iowa St.'),    (15,'Tennessee St.'),
    ],
}

# ── Lookup function ────────────────────────────────────────────────────────────
# Fixed get_stats fallback
def get_stats(team_name):
    """Get stats for a team, with fuzzy fallback."""
    row = df_2026[df_2026['TEAM'] == team_name]
    if len(row) == 0:
        row = df_2026[df_2026['TEAM'].str.contains(team_name.split()[0], case=False, na=False)]
    if len(row) == 0:
        print(f"WARNING: {team_name} not found, using average stats")
        return df_2026.mean(numeric_only=True)  # fixed fallback
    return row.iloc[0]

def predict_game(team_a, seed_a, team_b, seed_b):
    """Predict a single game, return (win_prob_a, predicted_winner, winner_seed)."""
    stats_a = get_stats(team_a)
    stats_b = get_stats(team_b)

    features = {}
    stat_map = {
        'KADJ EM_DIFF': 'KADJ EM',
        'KADJ O_DIFF':  'KADJ O',
        'KADJ D_DIFF':  'KADJ D',
        'BADJ EM_DIFF': 'BADJ EM',
        'BADJ O_DIFF':  'BADJ O',
        'BADJ D_DIFF':  'BADJ D',
        'BARTHAG_DIFF': 'BARTHAG',
        'EFG%_DIFF':    'EFG%',
        'EFG%D_DIFF':   'EFG%D',
        'TOV%_DIFF':    'TOV%',
        'TOV%D_DIFF':   'TOV%D',
        'OREB%_DIFF':   'OREB%',
        'DREB%_DIFF':   'DREB%',
        'ELITE SOS_DIFF':'ELITE SOS',
        'WAB_DIFF':     'WAB',
        'WIN%_DIFF':    'WIN%',
        'TALENT_DIFF':  'TALENT',
        'EXP_DIFF':     'EXP',
        'SEED_DIFF':    None,
    }

    row = {}
    for feat, stat in stat_map.items():
        if stat is None:
            row[feat] = seed_a - seed_b
        else:
            val_a = stats_a.get(stat, 0) if hasattr(stats_a, 'get') else getattr(stats_a, stat, 0)
            val_b = stats_b.get(stat, 0) if hasattr(stats_b, 'get') else getattr(stats_b, stat, 0)
            row[feat] = val_a - val_b

    X_game = pd.DataFrame([row])[top_features]
    prob_a = rf_final.predict_proba(X_game)[0][1]

    if prob_a >= 0.5:
        return prob_a, team_a, seed_a
    else:
        return prob_a, team_b, seed_b

# ── Simulate full bracket ──────────────────────────────────────────────────────
round_names = {64:'Round of 64', 32:'Round of 32', 16:'Sweet 16',
               8:'Elite 8', 4:'Final Four', 2:'Championship'}
all_results = []

def simulate_region(region_name, teams):
    """Simulate one region through Elite 8."""
    print(f"\n{'='*50}")
    print(f"  {region_name.upper()} REGION")
    print(f"{'='*50}")
    current_round = list(teams)  # list of (seed, team)
    round_size = 64

    while len(current_round) > 1:
        next_round = []
        print(f"\n--- {round_names[round_size]} ---")
        for i in range(0, len(current_round), 2):
            seed_a, team_a = current_round[i]
            seed_b, team_b = current_round[i+1]
            prob_a, winner, winner_seed = predict_game(team_a, seed_a, team_b, seed_b)
            loser = team_b if winner == team_a else team_a
            prob_winner = prob_a if winner == team_a else 1 - prob_a
            print(f"  ({seed_a}) {team_a:20s} vs ({seed_b}) {team_b:20s}  -->  "
                  f"({winner_seed}) {winner} wins  [{prob_winner:.1%}]")
            all_results.append({
                'region': region_name, 'round': round_names[round_size],
                'team_a': team_a, 'seed_a': seed_a,
                'team_b': team_b, 'seed_b': seed_b,
                'prob_a': round(prob_a, 3),
                'predicted_winner': winner, 'winner_seed': winner_seed
            })
            next_round.append((winner_seed, winner))
        current_round = next_round
        round_size //= 2

    return current_round[0]  # returns (seed, team) of region winner

# Simulate all 4 regions
final_four = []
for region, teams in bracket_2026.items():
    winner = simulate_region(region, teams)
    final_four.append((winner[0], winner[1], region))
    print(f"\n  >>> {region} Champion: ({winner[0]}) {winner[1]}")

# ── Final Four ─────────────────────────────────────────────────────────────────
print(f"\n{'='*50}")
print(f"  FINAL FOUR")
print(f"{'='*50}")

# East vs South, West vs Midwest
ff_games = [
    (final_four[0], final_four[1]),  # East vs South
    (final_four[2], final_four[3]),  # West vs Midwest
]

championship = []
for (seed_a, team_a, reg_a), (seed_b, team_b, reg_b) in ff_games:
    prob_a, winner, winner_seed = predict_game(team_a, seed_a, team_b, seed_b)
    loser = team_b if winner == team_a else team_a
    prob_winner = prob_a if winner == team_a else 1 - prob_a
    print(f"\n  ({seed_a}) {team_a} [{reg_a}] vs ({seed_b}) {team_b} [{reg_b}]")
    print(f"  --> ({winner_seed}) {winner} wins [{prob_winner:.1%}]")
    championship.append((winner_seed, winner))

# ── Championship ───────────────────────────────────────────────────────────────
print(f"\n{'='*50}")
print(f"  NATIONAL CHAMPIONSHIP")
print(f"{'='*50}")
(seed_a, team_a), (seed_b, team_b) = championship
prob_a, winner, winner_seed = predict_game(team_a, seed_a, team_b, seed_b)
prob_winner = prob_a if winner == team_a else 1 - prob_a
print(f"\n  ({seed_a}) {team_a} vs ({seed_b}) {team_b}")
print(f"  --> NATIONAL CHAMPION: ({winner_seed}) {winner} [{prob_winner:.1%}]")

# ── Save results ───────────────────────────────────────────────────────────────
df_results = pd.DataFrame(all_results)
df_results.to_csv('2026_bracket_predictions.csv', index=False)
print(f"\nSaved to 2026_bracket_predictions.csv")
# Out:
# ...
#   EAST REGION
# ...
#
# --- Round of 64 ---
#   (1) Duke                 vs (16) Siena                 -->  (1) Duke wins  [72.6%]
#   (8) Ohio St.             vs (9) TCU                   -->  (8) Ohio St. wins  [62.8%]
#   (5) St. John's           vs (12) N. Iowa               -->  (5) St. John's wins  [89.8%]
#   (4) Kansas               vs (13) Cal Baptist           -->  (4) Kansas wins  [86.0%]
#   (6) Louisville           vs (11) South Florida         -->  (6) Louisville wins  [89.4%]
#   (3) Michigan St.         vs (14) N. Dakota St.         -->  (3) Michigan St. wins  [86.0%]
#   (7) UCLA                 vs (10) UCF                   -->  (7) UCLA wins  [74.6%]
#   (2) UConn                vs (15) Furman                -->  (2) UConn wins  [76.6%]
#
# --- Round of 32 ---
#   (1) Duke                 vs (8) Ohio St.              -->  (1) Duke wins  [61.0%]
#   (5) St. John's           vs (4) Kansas                -->  (5) St. John's wins  [57.6%]
# ...

# %%
# Check for duplicates
print(df_2026[df_2026.duplicated(subset='TEAM', keep=False)][['TEAM','KADJ EM','BARTHAG']])
# Out:
# Empty DataFrame
# Columns: [TEAM, KADJ EM, BARTHAG]
# Index: []
